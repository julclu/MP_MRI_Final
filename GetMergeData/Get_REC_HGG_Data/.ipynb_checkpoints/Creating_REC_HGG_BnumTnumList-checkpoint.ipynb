# %%
import os 
import glob
import pandas as pd
import numpy as np

# %%
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
path = pd.read_csv('rec_hgg_path_jan_2019.csv')
path.shape
# Out:
# (353, 34)

# %%
## remove the tumor_cell_evaluations that don't have entries
path_withoutNaN = path.dropna(subset = ['tumor_cell_evaluation'])
path_withoutNaN.shape
# Out:
# (226, 34)

# %%
## remove duplicates for t_number
path_withoutNaN_noDup = path_withoutNaN.drop_duplicates('t_number')

# %%
path_withoutNaN_noDup.shape
# Out:
# (79, 34)

# %%
## remove Grade II that are in there accidentally: 
path_withoutNaN_noDup_noGII = path_withoutNaN_noDup[path_withoutNaN_noDup.current_hist_grade != "Grade II"]

# %%
path_withoutNaN_noDup_noGII.shape
# Out:
# (79, 34)

# %%
path_withoutNaN_noDup_noGII.t_number = path_withoutNaN_noDup_noGII.t_number.astype(int)

# %%
path_withoutNaN_noDup_noGII.shape
# Out:
# (79, 34)

# %%
path_withoutNaN_noDup_noGII.head()
# Out:
#     b_number  t_number  sf_number current_scan_date current_surgery_date  \
# 0       1338      8773     9727.0        2013-10-02           2013-10-03
# 4       2947      8775     9729.0        2013-10-06           2013-10-07
# 8       3472      8783     9739.0        2013-10-14           2013-10-15
# 10      3499      8869     9795.0        2013-12-10           2013-12-11
# 12      3125      8878     9801.0        2013-12-15           2013-12-16
#
#     post_t_number post_scan_date current_hist_grade current_hist_type vial_id  \
# 0          9877.0     2013-10-04           Grade IV      Glioblastoma   60B60
# 4          9878.0     2013-10-08           Grade IV      Glioblastoma    1B61
# 8          9880.0     2013-10-16   Treatment Effect  Treatment Effect   31B61
# 10         9881.0     2013-12-12           Grade IV      Glioblastoma   65B60
# 12         9892.0     2013-12-17           Grade IV      Glioblastoma   42B61
#
# ...

# %%
path_withoutNaN_noDup_noGII.b_number = [bnum  if len(str(bnum)) == 4 else "0"+str(bnum)[0:len(bnum)] for bnum in path_withoutNaN_noDup_noGII.b_number.astype(str)]

# %%
path_withoutNaN_noDup_noGII.b_number = "b"+path_withoutNaN_noDup_noGII.b_number

# %%
path_withoutNaN_noDup_noGII.head()
# Out:
#    b_number  t_number  sf_number current_scan_date current_surgery_date  \
# 0     b1338      8773     9727.0        2013-10-02           2013-10-03
# 4     b2947      8775     9729.0        2013-10-06           2013-10-07
# 8     b3472      8783     9739.0        2013-10-14           2013-10-15
# 10    b3499      8869     9795.0        2013-12-10           2013-12-11
# 12    b3125      8878     9801.0        2013-12-15           2013-12-16
#
#     post_t_number post_scan_date current_hist_grade current_hist_type vial_id  \
# 0          9877.0     2013-10-04           Grade IV      Glioblastoma   60B60
# 4          9878.0     2013-10-08           Grade IV      Glioblastoma    1B61
# 8          9880.0     2013-10-16   Treatment Effect  Treatment Effect   31B61
# 10         9881.0     2013-12-12           Grade IV      Glioblastoma   65B60
# 12         9892.0     2013-12-17           Grade IV      Glioblastoma   42B61
#
# ...

# %%
path_withoutNaN_noDup_noGII.t_number = "t"+path_withoutNaN_noDup_noGII.t_number.astype(str)

# %%
path_withoutNaN_noDup_noGII.head()
# Out:
#    b_number t_number  sf_number current_scan_date current_surgery_date  \
# 0     b1338    t8773     9727.0        2013-10-02           2013-10-03
# 4     b2947    t8775     9729.0        2013-10-06           2013-10-07
# 8     b3472    t8783     9739.0        2013-10-14           2013-10-15
# 10    b3499    t8869     9795.0        2013-12-10           2013-12-11
# 12    b3125    t8878     9801.0        2013-12-15           2013-12-16
#
#     post_t_number post_scan_date current_hist_grade current_hist_type vial_id  \
# 0          9877.0     2013-10-04           Grade IV      Glioblastoma   60B60
# 4          9878.0     2013-10-08           Grade IV      Glioblastoma    1B61
# 8          9880.0     2013-10-16   Treatment Effect  Treatment Effect   31B61
# 10         9881.0     2013-12-12           Grade IV      Glioblastoma   65B60
# 12         9892.0     2013-12-17           Grade IV      Glioblastoma   42B61
#
# ...

# %%
## only want to keep the bnums that are in the /archived folder, else won't be able to process them correctly: 
bnums_in_dir = os.listdir('/data/RECglioma/')

# %%
bnum_tnum_list = path_withoutNaN_noDup_noGII[['b_number', 't_number']]
bnum_tnum_list.head()
# Out:
#    b_number t_number
# 0     b1338    t8773
# 4     b2947    t8775
# 8     b3472    t8783
# 10    b3499    t8869
# 12    b3125    t8878

# %%
bnum_tnum_list_indir = bnum_tnum_list[bnum_tnum_list['b_number'].isin(bnums_in_dir) ]

# %%
bnum_tnum_list_indir.shape
# Out:
# (79, 2)

# %%
bnum_tnum_list_indir['DUMMY']="DUMMY"

# %%
bnum_tnum_list_indir.head()
# Out:
#    b_number t_number  DUMMY
# 0     b1338    t8773  DUMMY
# 4     b2947    t8775  DUMMY
# 8     b3472    t8783  DUMMY
# 10    b3499    t8869  DUMMY
# 12    b3125    t8878  DUMMY

# %%
bnum_tnum_list_indir.to_csv('rec_hgg_process_list.79.csv', index = False, header =False )
